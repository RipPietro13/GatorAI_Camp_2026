# %%
def addition(num1, num2):

    num1 = int(input("Enter first number: "))
    num2 = int(input("Enter second number: ")) 

    print(f"adding the numbers {num1} and {num2} gives {num1 + num2}")
    return sum

final_result=addition(2,3)
print(f"now that we have added the numbers it gave us {final_result}")
# Out:
# adding the numbers 2 and 3 gives 5
# now that we have added the numbers it gave us <built-in function sum>
